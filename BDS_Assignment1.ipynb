# %%
import pandas as pd

# %%
# from google.colab import drive
# drive.mount('/content/drive/')
# from google.colab import drive
# drive.flush_and_unmount()

# %%
df = pd.read_csv('/Parking_Violations_Issued_-_Fiscal_Year_2022.csv')
df.shape

# %%
df = pd.read_csv(r'C:\Program Files\MongoDB\Server\5.0\bin\Parking_Violations_Issued_-_Fiscal_Year_2022.csv')
df.shape
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6312\3884526313.py:1: DtypeWarning: Columns (0,9,17,18,20,22,23,29,30,31,32,36,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Program Files\MongoDB\Server\5.0\bin\Parking_Violations_Issued_-_Fiscal_Year_2022.csv')
# (644585, 43)

# %%
df.head(2)
# Out:
#   Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0     1457617912  JEB5683                 NY        PAS  06/25/2021
# 1     1457617924  JAN2986                 NY        PAS  06/25/2021
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency Street Code1  \
# 0            40.0               VAN         FORD              P        63430
# 1            20.0              SUBN        DODGE              P        13490
#
#    ...  Vehicle Color  Unregistered Vehicle?  Vehicle Year  Meter Number  \
# 0  ...             GY                    0.0        2007.0             -
# 1  ...            BLU                    0.0        2007.0             -
#
#    Feet From Curb  Violation Post Code  Violation Description  \
# 0             3.0                  NaN                    NaN
# 1             0.0                  NaN                    NaN
#
#   No Standing or Stopping Violation Hydrant Violation Double Parking Violation
# ...

# %%
df.isna().sum()
# Out:
# Summons Number                            0
# Plate ID                                 10
# Registration State                        4
# Plate Type                                4
# Issue Date                                4
# Violation Code                            4
# Vehicle Body Type                      2355
# Vehicle Make                            751
# Issuing Agency                            4
# Street Code1                              4
# Street Code2                              5
# Street Code3                              5
# Vehicle Expiration Date                   5
# Violation Location                   358495
# Violation Precinct                        5
# Issuer Precinct                           5
# Issuer Code                               5
# Issuer Command                       358228
# Issuer Squad                         381960
# Violation Time                           15
# Time First Observed                  605088
# ...

# %%
df[df['Issue Date'].isna()]
# Out:
#                         Summons Number Plate ID Registration State Plate Type  \
# 644581                  "error" : true      NaN                NaN        NaN
# 644582    "message" : "Internal error"      NaN                NaN        NaN
# 644583                  "status" : 500      NaN                NaN        NaN
# 644584                               }      NaN                NaN        NaN
#
#        Issue Date  Violation Code Vehicle Body Type Vehicle Make  \
# 644581        NaN             NaN               NaN          NaN
# 644582        NaN             NaN               NaN          NaN
# 644583        NaN             NaN               NaN          NaN
# 644584        NaN             NaN               NaN          NaN
#
#        Issuing Agency Street Code1  ...  Vehicle Color  Unregistered Vehicle?  \
# 644581            NaN          NaN  ...            NaN                    NaN
# 644582            NaN          NaN  ...            NaN                    NaN
# ...

# %% [markdown]
# #### 1) Find the number of tickets raised for the year 2022

# %%
df['Issue_Year'] = pd.to_datetime(df['Issue Date']).dt.year
df[df['Issue_Year']==2022]['Summons Number'].nunique()
# df['Issue_Year'].unique()
# Out:
# 11

# %% [markdown]
# #### 2) Identify the vehicles registered in New York (NY) city whose violation code is 40.

# %%
df[df['Plate ID'].isna()]
# Out:
#                         Summons Number Plate ID Registration State Plate Type  \
# 20627                       2000355602      NaN                 NY        PAS
# 20628                       2000355614      NaN                 NY        PAS
# 20629                       2000355626      NaN                 NY        PAS
# 20735                       2001024976      NaN                 99        PAS
# 28504                       2002572835      NaN                 99        999
# 32151                       2002698533      NaN                 99        PAS
# 644581                  "error" : true      NaN                NaN        NaN
# 644582    "message" : "Internal error"      NaN                NaN        NaN
# 644583                  "status" : 500      NaN                NaN        NaN
# 644584                               }      NaN                NaN        NaN
#
#         Issue Date  Violation Code Vehicle Body Type Vehicle Make  \
# ...

# %%
df[(df['Registration State']=='NY')&(df['Violation Code']==40)]['Plate ID'].nunique()
# Out:
# 9543

# %% [markdown]
# #### 3) What are the number of states for which tickets have been filed for year 2020? Also

# %% [markdown]
# #### provide the list of the states.

# %% [markdown]
# #### 4) Count the numbers of vehicles registered in TX for the year 2022.

# %% [markdown]
# #### 5) Identify the vehicle involved in parking violations between 2020 to 2022.

# %% [markdown]
# #### 6) What are the top 10 most frequently occurring violation codes?

# %% [markdown]
# #### 7) Count the number of vehicles whose 'street code1 is ‘0’

# %% [markdown]
# #### 8) What are the number of incidents for which address is missing? Consider the Street Codes attributes, i.e. "Street Code 1" or "Street Code 2" or "Street Code 3".

# %% [markdown]
# #### 9) What are the top 10 most frequently occurring violation codes?

# %% [markdown]
# #### 10)What is the observation with respect to the parking tickets issued based on the vehicle make?

# %% [markdown]
# #### 11)Display all the vehicles whose street code1 is ‘0’ and issuing agency is ‘P’.

# %% [markdown]
# #### 12)Find out the frequencies of tickets raised per season. You can make use of Google search to specify the definition of season.

# %% [markdown]
# #### 13)For each of the season identified in (6) above, what are the three most violations.
